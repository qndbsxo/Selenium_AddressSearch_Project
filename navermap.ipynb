# %%
import pandas as pd
df = pd.read_csv('133.인천광역시_서구_식품관련업_20210702_검색완료.csv', encoding='cp949')[1303:2213]
df = df[df['Result'] == 'X']
df['도로명'] = df['소재지(도로명)'].str.split(' ', expand=True)[2]
df
# Out:
#         연번        업종명             업소명  \
# 1303  1304  즉석판매제조가공업        맛과멋그리고향기
# 1306  1307  즉석판매제조가공업            행복식품
# 1307  1308  즉석판매제조가공업            가원수산
# 1308  1309  즉석판매제조가공업          주식회사비드
# 1313  1314  즉석판매제조가공업           힘찬건강원
# ...    ...        ...             ...
# 2208  2209     위탁급식영업          미래그린식당
# 2209  2210     위탁급식영업  (주)동원홈푸드 이오시스템
# 2210  2211     위탁급식영업        신세계푸드 리팩
# 2211  2212     위탁급식영업      비케이테크 구내식당
# 2212  2213     위탁급식영업            연우푸드
#
#                                          소재지(도로명)  \
# 1303           인천광역시 서구 청라커낼로288번길 26, 282호 (청라동)
# 1306            인천광역시 서구 석남로110번길 4-4, 1층일부 (석남동)
# 1307  인천광역시 서구 승학로 224, 드림식자재마트내 1층일부(수산코너) (심곡동)
# 1308                인천광역시 서구 탁옥로 10, 1층 일부호 (심곡동)
# 1313              인천광역시 서구 중봉대로 800, 1층 일부호 (경서동)
# ...                                           ...
# 2208          인천광역시 서구 중봉대로198번길 33 (가좌동, 602-36)
# 2209                       인천광역시 서구 가재울로 38 (가좌동)
# 2210                       인천광역시 서구 가재울로 27 (가좌동)
# 2211        인천광역시 서구 건지로97번길 33-32 (석남동, 223-233)
# 2212                    인천광역시 서구 가좌로 92, 4층 (가좌동)
#
#                            소재지(지번)            전화번호     데이터기준일자 Result  \
# 1303      인천광역시 서구 청라동 157-10 282호             NaN  2021-07-02      X
# 1306          인천광역시 서구 석남동 578-42              NaN  2021-07-02      X
# 1307  인천광역시 서구 심곡동 251-18 드림식자재마트              NaN  2021-07-02      X
# 1308     인천광역시 서구 심곡동 335-4 1층 일부호             NaN  2021-07-02      X
# 1313    인천광역시 서구 경서동 350-59 1층 일부호             NaN  2021-07-02      X
# ...                            ...             ...         ...    ...
# 2208          인천광역시 서구 가좌동 602-36    032- 572-3455  2021-07-02      X
# 2209           인천광역시 서구 가좌동 542-7    032- 290-1613  2021-07-02      X
# 2210          인천광역시 서구 가좌동 552-27    032- 583-9983  2021-07-02      X
# 2211         인천광역시 서구 석남동 223-233    032- 575-1201  2021-07-02      X
# 2212        인천광역시 서구 가좌동 473-3 4층    032- 717-6190  2021-07-02      X
#
#              도로명
# 1303  청라커낼로288번길
# 1306    석남로110번길
# 1307         승학로
# 1308         탁옥로
# 1313        중봉대로
# ...          ...
# 2208   중봉대로198번길
# 2209        가재울로
# 2210        가재울로
# 2211     건지로97번길
# 2212         가좌로
#
# [452 rows x 9 columns]
